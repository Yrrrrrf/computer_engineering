# %% [markdown]
# ### Manage data

# %%
import pandas as pd
import numpy as np

from pathlib import Path 
path = Path().absolute().parent.parent.parent.parent / 'resources' / 'data' / 'bestsellers with categories.csv'

# %%
data = pd.read_csv(path).head(10)  # read the first 10 rows
data
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 7                     A Gentleman in Moscow: A Novel
# 8      A Higher Loyalty: Truth, Lies, and Leadership
# 9                          A Man Called Ove: A Novel
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 5       George R. R. Martin          4.4    12643     11  2011      Fiction
# 6       George R. R. Martin          4.7    19735     30  2014      Fiction
# 7               Amor Towles          4.7    19699     15  2017      Fiction
# 8               James Comey          4.7     5983      3  2018  Non Fiction
# 9           Fredrik Backman          4.6    23848      8  2016      Fiction

# %% [markdown]
# ### Drop

# %%
data.drop(['Price', 'Genre'], axis=1, inplace=True)  # inplace = True : modify the original data
# axis = 0 : drop rows
# axis = 1 : drop columns

# %%
data.drop(range(1, 10, 2), axis=0, inplace=True)  # drop rows with odd index
data.drop_duplicates(subset=['Name'], keep='first', inplace=True)  # keep the first occurence (drop duplicates)

# %%
data
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 2            12 Rules for Life: An Antidote to Chaos
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 8      A Higher Loyalty: Truth, Lies, and Leadership
#
#                      Author  User Rating  Reviews  Year
# 0                  JJ Smith          4.7    17350  2016
# 2        Jordan B. Peterson          4.7    18979  2018
# 4  National Geographic Kids          4.8     7665  2019
# 6       George R. R. Martin          4.7    19735  2014
# 8               James Comey          4.7     5983  2018

# %% [markdown]
# ### Add

# %%
data['New Column'] = np.nan  # add a new column with NaN values

# %%
# data['New Column'] = 1  # add 1 to all rows
data['New Column'] = range(1,10,2)  # add data to the new column
data
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 2            12 Rules for Life: An Antidote to Chaos
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 8      A Higher Loyalty: Truth, Lies, and Leadership
#
#                      Author  User Rating  Reviews  Year  New Column
# 0                  JJ Smith          4.7    17350  2016           1
# 2        Jordan B. Peterson          4.7    18979  2018           3
# 4  National Geographic Kids          4.8     7665  2019           5
# 6       George R. R. Martin          4.7    19735  2014           7
# 8               James Comey          4.7     5983  2018           9

# %%
### add row
new_row = {'Name': 'New Book', 'Author': 'New Author', 'User Rating': 4.5, 'Reviews': 1000, 'Year': 2020, 'New Column': 1}
# data = data.append(new_row, ignore_index=True)  # add a row to the end of the data (will be deprecated in the future)
data = pd.concat([data, pd.DataFrame([new_row])])

# duplicate rows
pd.concat([data, data], ignore_index=True)
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1             12 Rules for Life: An Antidote to Chaos
# 2   5,000 Awesome Facts (About Everything!) (Natio...
# 3   A Game of Thrones / A Clash of Kings / A Storm...
# 4       A Higher Loyalty: Truth, Lies, and Leadership
# 5                                            New Book
# 6                       10-Day Green Smoothie Cleanse
# 7             12 Rules for Life: An Antidote to Chaos
# 8   5,000 Awesome Facts (About Everything!) (Natio...
# 9   A Game of Thrones / A Clash of Kings / A Storm...
# 10      A Higher Loyalty: Truth, Lies, and Leadership
# 11                                           New Book
#
#                       Author  User Rating  Reviews  Year  New Column
# 0                   JJ Smith          4.7    17350  2016           1
# 1         Jordan B. Peterson          4.7    18979  2018           3
# 2   National Geographic Kids          4.8     7665  2019           5
# 3        George R. R. Martin          4.7    19735  2014           7
# 4                James Comey          4.7     5983  2018           9
# 5                 New Author          4.5     1000  2020           1
# 6                   JJ Smith          4.7    17350  2016           1
# 7         Jordan B. Peterson          4.7    18979  2018           3
# 8   National Geographic Kids          4.8     7665  2019           5
# 9        George R. R. Martin          4.7    19735  2014           7
# 10               James Comey          4.7     5983  2018           9
# 11                New Author          4.5     1000  2020           1

# %% [markdown]
# ###
