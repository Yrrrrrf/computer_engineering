# %% [markdown]
# # [Relational Plot (replot)](https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot)
#
# - [Scatterplot](https://seaborn.pydata.org/generated/seaborn.scatterplot.html#seaborn.scatterplot)
# - [Lineplot](https://seaborn.pydata.org/generated/seaborn.lineplot.html#seaborn.lineplot)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set(style="ticks")  # set the style of the plots

# %%
tips = sns.load_dataset("tips")
tips.head(3)

fmri = sns.load_dataset("fmri")
fmri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %% [markdown]
# ### [Scatterplot](https://seaborn.pydata.org/generated/seaborn.scatterplot.html#seaborn.scatterplot)
#
# This is the default plot kind when using `relplot()`
# - `kind="scatter"` (default)

# %%
scatter: sns.FacetGrid = sns.relplot(
    data=tips,
    x="total_bill",
    y="tip",
    hue="day",  # color by day
    style= "time",  # marker by time
    markers={"Lunch": "D", "Dinner": "s"},  # replace markers
    size="size",  # size by size
    kind="scatter",  # scatterplot

    col="time"  # separate by time
)

plt.show()

# %% [markdown]
# ### [Lineplot](https://seaborn.pydata.org/generated/seaborn.lineplot.html#seaborn.lineplot)
# - `kind="line"`
# - `ci=None` (default) to remove confidence interval
# - `sort=False` (default) to keep the order of the data points
# - `estimator=None` (default) to remove the line and keep the scatterplot

# %%
line: sns.FacetGrid = sns.relplot(
    data=fmri,
    x="timepoint",
    y="signal",
    kind="line",  # lineplot
    style="event",
    hue="region", col="region",
    col_wrap=2,  # wrap the columns (separate into multiple rows)
    # errorbar="sd",  # None, "sd", "ci" (default), "boot_traces", "boot_kde", "both_traces", "both_kde"
    markers=True
)
