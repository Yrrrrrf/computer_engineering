# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.hist(np.random.randn(1000), bins=20, color='g')
# Out:
# (array([  2.,   2.,   7.,  20.,  27.,  42.,  83., 108., 107., 134., 139.,
#         111.,  87.,  70.,  34.,  14.,   8.,   4.,   0.,   1.]),
#  array([-3.34696802, -2.99834743, -2.64972683, -2.30110624, -1.95248565,
#         -1.60386505, -1.25524446, -0.90662386, -0.55800327, -0.20938268,
#          0.13923792,  0.48785851,  0.83647911,  1.1850997 ,  1.53372029,
#          1.88234089,  2.23096148,  2.57958207,  2.92820267,  3.27682326,
#          3.62544386]),
#  <BarContainer object of 20 artists>)

# %%
#  create a lineplot

plt.plot([1,2,3,4], [1,4,9,16], 'bx')
