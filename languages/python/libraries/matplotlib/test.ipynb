# %%
# import
import matplotlib.pyplot as plt
import numpy as np

# %%
# set function
f = lambda x: x**2

# %%
# graphicate in 4k resolution
x = np.linspace(-2, 2, 4096)
y = f(x)

# %%
# plot and display function f(x)
plt.plot(x, y)
plt.show()

# %%
# save img
plt.imsave('f(x).png', y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # save img
# ----> 2 plt.imsave('f(x).png', y)
#
# File c:\Users\Yrrrrrf\Documents\computer_engineering\.venv\Lib\site-packages\matplotlib\pyplot.py:2136, in imsave(fname, arr, **kwargs)
#    2134 @_copy_docstring_and_deprecators(matplotlib.image.imsave)
#    2135 def imsave(fname, arr, **kwargs):
# -> 2136     return matplotlib.image.imsave(fname, arr, **kwargs)
#
# File c:\Users\Yrrrrrf\Documents\computer_engineering\.venv\Lib\site-packages\matplotlib\image.py:1637, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1635     pil_kwargs = pil_kwargs.copy()
#    1636 pil_shape = (rgba.shape[1], rgba.shape[0])
# -> 1637 image = PIL.Image.frombuffer(
#    1638     "RGBA", pil_shape, rgba, "raw", "RGBA", 0, 1)
#    1639 if format == "png":
# ...
